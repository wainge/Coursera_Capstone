# %% [markdown]
# **Introduction/Business Problem**

# %% [markdown]
# I'm looking to open a Sports Bar in Denver, Colorado, however, I do not know what the best area would be. My plan is
# to use FourSquare lcoation data to first identify clusters of neighbrhoods, then using the tips data, identify
# which which neighborhoods have the highest number of tips per bar, meaning they would be potnetailly be underserved. This problem/situation would serve for anyone looking to open a new business in an area and is looking to see if there is excess demand which could be taken advantage of or if there is anyone currently in an rea and wants to see if their area is under/iver served. It is important to understand to how much demand you ahve or may have in an area, so you know whether or not you have enough customers to be profitable in your business.

# %% [markdown]
# **Data**

# %% [markdown]
#     - Foursquare Location: The longitude and latitude data will be used to create clusters based on actual geolocation points.
#     - Foursquare Venue Data: The number of tips for each venue will be used as a total quantity to demonstrate popularity, can also use checked in numbers or ither data points.

# %% [markdown]
# Location Data:

# %% [markdown]
# |name 	| categories |	address 	| lat |	lng |	distance |	postalCode | 	cc |	city |	state |	country |	 formattedAddress |	crossStreet |	id |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# |29 |	Sheep Night Club & Sports Bar 	|Sports Bar |	500 Santa Fe Dr |	39.724315| 	-104.998281 |	2019 |	80204 	|US 	Denver |	CO| 	United States |	[500 Santa Fe Dr (W. 5th Ave), Denver, CO 80204] |	W. 5th Ave 	|587089c87ff1e46976da1ede|

# %% [markdown]
# Total Tips and other Venue Data

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation



 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

results = {'meta': {'code': 200, 'requestId': '60eefbc6dff951606de0dc1b'},
 'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
 'response': {'venue': {'id': '40e0b100f964a5200a041fe3',
   'name': 'Sports Column',
   'contact': {'phone': '3032961930',
    'formattedPhone': '(303) 296-1930',
    'twitter': 'sportscolumn'},
   'location': {'address': '1930 Blake Street',
    'lat': 39.753603,
    'lng': -104.994726,
    'labeledLatLngs': [{'label': 'display',
      'lat': 39.753603,
      'lng': -104.994726}],
    'distance': 1808,
    'postalCode': '80202',
    'cc': 'US',
    'city': 'Denver',
    'state': 'CO',
    'country': 'United States',
    'formattedAddress': ['1930 Blake Street', 'Denver, CO 80202']},
   'canonicalUrl': 'https://foursquare.com/v/sports-column/40e0b100f964a5200a041fe3',
   'categories': [{'id': '4bf58dd8d48988d11d941735',
     'name': 'Sports Bar',
     'pluralName': 'Sports Bars',
     'shortName': 'Sports Bar',
     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
      'suffix': '.png'},
     'primary': True},
    {'id': '4bf58dd8d48988d14e941735',
     'name': 'American Restaurant',
     'pluralName': 'American Restaurants',
     'shortName': 'American',
     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
      'suffix': '.png'}},
    {'id': '4bf58dd8d48988d11e941735',
     'name': 'Cocktail Bar',
     'pluralName': 'Cocktail Bars',
     'shortName': 'Cocktail',
     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
      'suffix': '.png'}}],
   'verified': False,
   'stats': {'tipCount': 33},
   'url': 'http://www.denversportscolumn.com',
   'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
   'likes': {'count': 66,
    'groups': [{'type': 'others', 'count': 66, 'items': []}],
    'summary': '66 Likes'},
   'like': False,
   'dislike': False,
   'ok': False,
   'rating': 6.2,
   'ratingColor': 'FFC800',
   'ratingSignals': 134,
   'delivery': {'id': '2039923',
    'url': 'https://www.grubhub.com/restaurant/sports-column-1930-blake-st-denver/2039923?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2039923',
    'provider': {'name': 'grubhub',
     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
      'sizes': [40, 50],
      'name': '/delivery_provider_grubhub_20180129.png'}}},
   'allowMenuUrlEdit': True,
   'beenHere': {'count': 0,
    'unconfirmedCount': 0,
    'marked': False,
    'lastCheckinExpiredAt': 0},
   'specials': {'count': 0, 'items': []},
   'photos': {'count': 154,
    'groups': [{'type': 'venue',
      'name': 'Venue photos',
      'count': 154,
      'items': [{'id': '4fc7e4d6e4b0936e6eef5a26',
        'createdAt': 1338500310,
        'source': {'name': 'Foursquare for iOS',
         'url': 'https://foursquare.com/download/#/iphone'},
        'prefix': 'https://fastly.4sqi.net/img/general/',
        'suffix': '/aUXmYTqfPiWjEVWgugB7VtzZyqZfne1EAqDfaO1p3-M.jpg',
        'width': 540,
        'height': 720,
        'user': {'id': '10696249',
         'firstName': 'Dee',
         'lastName': 'Schwerin',
         'gender': 'female',
         'countryCode': 'US',
         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
          'suffix': '/55SX2IMAT0F2QSCV.jpg'}},
        'visibility': 'public'}]}]},
   'reasons': {'count': 1,
    'items': [{'summary': 'Lots of people like this place',
      'type': 'general',
      'reasonName': 'rawLikesReason'}]},
   'description': 'Sports Bar in Denver, located in the heart of LoDo, just steps away from Coors Field that offers a full restaurant menu, HD TVs, drink specials, an outdoor rooftop patio and great service.',
   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
   'createdAt': 1088467200,
   'tips': {'count': 33,
    'groups': [{'type': 'following',
      'name': 'Tips from people you follow',
      'count': 0,
      'items': []},
     {'type': 'others',
      'name': 'All tips',
      'count': 33,
      'items': [{'id': '4e8fef6802d5ee38b69546e4',
        'createdAt': 1318055784,
        'text': 'Your mom was here.',
        'type': 'user',
        'canonicalUrl': 'https://foursquare.com/item/4e8fef6802d5ee38b69546e4',
        'likes': {'count': 4,
         'groups': [{'type': 'others',
           'count': 4,
           'items': [{'id': '209401',
             'firstName': 'Carrie',
             'lastName': 'Gottschalk',
             'gender': 'female',
             'countryCode': 'US',
             'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
              'suffix': '/J1INZBF1BDANN1YT.jpg'}},
            {'id': '19996017',
             'firstName': 'WILLIAM',
             'lastName': 'Penn',
             'gender': 'male',
             'countryCode': 'US',
             'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
              'suffix': '/LLALD12NW3X3KOYV.jpg'}},
            {'id': '10102064',
             'firstName': 'Natalie',
             'lastName': 'Williams',
             'gender': 'female',
             'countryCode': 'US',
             'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
              'suffix': '/Y5C3RO40ROOMC10S.jpg'}}]}],
         'summary': '4 likes'},
        'like': False,
        'logView': True,
        'agreeCount': 3,
        'disagreeCount': 0,
        'todo': {'count': 0},
        'user': {'id': '11902974',
         'firstName': 'Jesus',
         'lastName': 'Castillo',
         'gender': 'male',
         'countryCode': 'US',
         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
          'suffix': '/DTAJ2CT4PCS4EOL4.jpg'}}}]}]},
   'shortUrl': 'http://4sq.com/6t6cGB',
   'timeZone': 'America/Denver',
   'listed': {'count': 22,
    'groups': [{'type': 'others',
      'name': 'Lists from other people',
      'count': 22,
      'items': [{'id': '4ef37335d3e32dc398c63859',
        'name': 'social fun',
        'description': '',
        'type': 'others',
        'user': {'id': '10548165',
         'firstName': 'Alan',
         'lastName': 'Mann',
         'gender': 'male',
         'countryCode': 'US',
         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
          'suffix': '/MGL2SEF02IR2FQ5T.jpg'}},
        'editable': False,
        'public': True,
        'collaborative': False,
        'url': '/user/10548165/list/social-fun',
        'canonicalUrl': 'https://foursquare.com/user/10548165/list/social-fun',
        'createdAt': 1324577589,
        'updatedAt': 1498918885,
        'photo': {'id': '4e8de8f97beb42eabdf830f5',
         'createdAt': 1317923065,
         'prefix': 'https://fastly.4sqi.net/img/general/',
         'suffix': '/ZWCS25IMK5MBORLOSXQFQQC53TTBYWHBEJUYCCDYQB3ZJTGM.jpg',
         'width': 360,
         'height': 270,
         'user': {'id': '4426445',
          'firstName': 'Denver Westword',
          'gender': 'none',
          'countryCode': 'US',
          'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
           'suffix': '/EPUNAYTRW4LCP4TA.jpg'},
          'type': 'page'},
         'visibility': 'public'},
        'followers': {'count': 17},
        'listItems': {'count': 62,
         'items': [{'id': 't4c420a737beab7132ec19555',
           'createdAt': 1324578418,
           'tip': {'id': '4c420a737beab7132ec19555',
            'createdAt': 1279396467,
            'text': 'Drink: $2 wine, well drinks, domestic draft; $3 micro brews, imported draft, Washington Apple - SoCo Lime & Jager BombMon-Fri 3:30pm-6pmMon-Fri 10pm-2am',
            'type': 'user',
            'canonicalUrl': 'https://foursquare.com/item/4c420a737beab7132ec19555',
            'likes': {'count': 1,
             'groups': [{'type': 'others',
               'count': 1,
               'items': [{'id': '36046565',
                 'firstName': 'Jeanie',
                 'lastName': 'Dedmon',
                 'gender': 'female',
                 'countryCode': 'US',
                 'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
                  'suffix': '/YTMVI2LQ13X4BHG2.jpg'}}]}],
             'summary': '1 like'},
            'like': False,
            'logView': True,
            'agreeCount': 1,
            'disagreeCount': 0,
            'todo': {'count': 7},
            'saves': {},
            'user': {'id': '1048858',
             'firstName': 'DenverHappyHour',
             'gender': 'male',
             'countryCode': 'US',
             'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
              'suffix': '/NISAQIWNPOBQLOYB.png'}}}}]}},
       {'id': '4f874d40e4b0ab0c191fcd0b',
        'name': 'Top Local Bars for Avs fans',
        'description': 'In Denver looking for an Avs bar? We got you covered!',
        'type': 'others',
        'user': {'id': '3534006',
         'firstName': 'NHL',
         'gender': 'none',
         'countryCode': 'US',
         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
          'suffix': '/QYHUTDMMT1J1HEZN.jpg'},
         'type': 'page'},
        'editable': False,
        'public': True,
        'collaborative': False,
        'url': '/nhl/list/top-local-bars-for-avs-fans',
        'canonicalUrl': 'https://foursquare.com/nhl/list/top-local-bars-for-avs-fans',
        'createdAt': 1334267200,
        'updatedAt': 1431111304,
        'logView': True,
        'followers': {'count': 24},
        'listItems': {'count': 11,
         'items': [{'id': 'v40e0b100f964a5200a041fe3',
           'createdAt': 1334267302}]}}]}]},
   'hours': {'status': 'Closed until 11:00 AM',
    'richStatus': {'entities': [], 'text': 'Closed until 11:00 AM'},
    'isOpen': False,
    'isLocalHoliday': False,
    'dayData': [],
    'timeframes': [{'days': 'Mon–Fri',
      'includesToday': True,
      'open': [{'renderedTime': '11:00 AM–2:00 AM'}],
      'segments': []},
     {'days': 'Sat',
      'open': [{'renderedTime': '9:00 AM–2:00 AM'}],
      'segments': []},
     {'days': 'Sun',
      'open': [{'renderedTime': '10:00 AM–2:00 AM'}],
      'segments': []}]},
   'popular': {'isOpen': False,
    'isLocalHoliday': False,
    'timeframes': [{'days': 'Today',
      'includesToday': True,
      'open': [{'renderedTime': '5:00 PM–7:00 PM'}],
      'segments': []},
     {'days': 'Thu',
      'open': [{'renderedTime': '5:00 PM–1:00 AM'}],
      'segments': []},
     {'days': 'Fri',
      'open': [{'renderedTime': '4:00 PM–1:00 AM'}],
      'segments': []},
     {'days': 'Sat',
      'open': [{'renderedTime': '10:00 AM–2:00 AM'}],
      'segments': []},
     {'days': 'Sun',
      'open': [{'renderedTime': '10:00 AM–8:00 PM'}],
      'segments': []},
     {'days': 'Mon',
      'open': [{'renderedTime': '5:00 PM–8:00 PM'}],
      'segments': []},
     {'days': 'Tue',
      'open': [{'renderedTime': '6:00 PM–7:00 PM'}],
      'segments': []}]},
   'seasonalHours': [],
   'defaultHours': {'status': 'Closed until 11:00 AM',
    'richStatus': {'entities': [], 'text': 'Closed until 11:00 AM'},
    'isOpen': False,
    'isLocalHoliday': False,
    'dayData': [],
    'timeframes': [{'days': 'Mon–Fri',
      'includesToday': True,
      'open': [{'renderedTime': '11:00 AM–2:00 AM'}],
      'segments': []},
     {'days': 'Sat',
      'open': [{'renderedTime': '9:00 AM–2:00 AM'}],
      'segments': []},
     {'days': 'Sun',
      'open': [{'renderedTime': '10:00 AM–2:00 AM'}],
      'segments': []}]},
   'pageUpdates': {'count': 0, 'items': []},
   'inbox': {'count': 0, 'items': []},
   'attributes': {'groups': [{'type': 'price',
      'name': 'Price',
      'summary': '$$',
      'count': 1,
      'items': [{'displayName': 'Price',
        'displayValue': '$$',
        'priceTier': 2}]},
     {'type': 'reservations',
      'name': 'Reservations',
      'count': 3,
      'items': [{'displayName': 'Reservations', 'displayValue': 'No'}]},
     {'type': 'payments',
      'name': 'Credit Cards',
      'summary': 'Credit Cards',
      'count': 7,
      'items': [{'displayName': 'Credit Cards',
        'displayValue': 'Yes (incl. American Express)'}]},
     {'type': 'outdoorSeating',
      'name': 'Outdoor Seating',
      'summary': 'Outdoor Seating',
      'count': 1,
      'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
     {'type': 'wifi',
      'name': 'Wi-Fi',
      'summary': 'Wi-Fi',
      'count': 1,
      'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]},
     {'type': 'serves',
      'name': 'Menus',
      'summary': 'Happy Hour',
      'count': 8,
      'items': [{'displayName': 'Happy Hour', 'displayValue': 'Happy Hour'}]},
     {'type': 'drinks',
      'name': 'Drinks',
      'summary': 'Beer, Full Bar & Cocktails',
      'count': 5,
      'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
       {'displayName': 'Full Bar', 'displayValue': 'Full Bar'},
       {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]},
     {'type': 'touchTunes',
      'name': 'TouchTunes Jukebox',
      'summary': 'Yes',
      'count': 1,
      'items': [{'displayName': 'No', 'displayValue': 'Yes'}]}]},
   'bestPhoto': {'id': '4fc7e4d6e4b0936e6eef5a26',
    'createdAt': 1338500310,
    'source': {'name': 'Foursquare for iOS',
     'url': 'https://foursquare.com/download/#/iphone'},
    'prefix': 'https://fastly.4sqi.net/img/general/',
    'suffix': '/aUXmYTqfPiWjEVWgugB7VtzZyqZfne1EAqDfaO1p3-M.jpg',
    'width': 540,
    'height': 720,
    'visibility': 'public'},
   'colors': {'highlightColor': {'photoId': '4fc7e4d6e4b0936e6eef5a26',
     'value': -14675952},
    'highlightTextColor': {'photoId': '4fc7e4d6e4b0936e6eef5a26', 'value': -1},
    'algoVersion': 3}}}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venue']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
pd.set_option('display.max_columns', None)
dataframe.head()
# Out:
# <ipython-input-9-b9ac7cb784d6>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id           name  \
# 0  40e0b100f964a5200a041fe3  Sports Column
#
#                                         canonicalUrl  \
# 0  https://foursquare.com/v/sports-column/40e0b10...
#
#                                           categories  verified  \
# 0  [{'id': '4bf58dd8d48988d11d941735', 'name': 'S...     False
#
#                                  url   like  dislike     ok  rating  \
# 0  http://www.denversportscolumn.com  False    False  False     6.2
#
#   ratingColor  ratingSignals  allowMenuUrlEdit  \
# 0      FFC800            134              True
#
#                                          description   createdAt  \
# 0  Sports Bar in Denver, located in the heart of ...  1088467200
#
#                 shortUrl        timeZone seasonalHours contact.phone  \
# ...
